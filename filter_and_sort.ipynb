# %% [markdown]
# # Filtering and Sorting the data

# %%
import pandas as pd

data = pd.read_csv('Data/sales.csv', index_col='State')

# %%
highest_sales = (data['Sales']>300)
highest_sales
# Out:
# State
# California    False
# California    False
# California    False
# California     True
# California    False
#               ...
# Wisconsin     False
# Wisconsin     False
# Wisconsin     False
# Wisconsin     False
# Wisconsin     False
# Name: Sales, Length: 4241, dtype: bool

# %%
data.loc[highest_sales]
# Out:
#             Total Expenses         Product  Sales   Market Size  Profit  \
# State
# California           113.0  Decaf Espresso  576.0  Major Market   216.0
# California            99.0           Lemon  582.0  Major Market   291.0
# California           142.0       Columbian  687.0  Major Market   364.0
# California           166.0       Columbian  902.0  Major Market   508.0
# California           139.0       Columbian  664.0  Major Market   349.0
# ...                    ...             ...    ...           ...     ...
# Washington            71.0       Chamomile  329.0  Small Market   171.0
# Washington            73.0       Chamomile  334.0  Small Market   171.0
# Washington            75.0       Chamomile  347.0  Small Market   179.0
# Wisconsin            149.0       Columbian  317.0  Small Market    35.0
# Wisconsin            139.0       Columbian  314.0  Small Market    48.0
#
#              Market  Marketing Product Type  Inventory     Type
# State
# ...

# %%
data.loc[highest_sales,['Product', 'Profit', 'Sales']]
# Out:
#                    Product  Profit  Sales
# State
# California  Decaf Espresso   216.0  576.0
# California           Lemon   291.0  582.0
# California       Columbian   364.0  687.0
# California       Columbian   508.0  902.0
# California       Columbian   349.0  664.0
# ...                    ...     ...    ...
# Washington       Chamomile   171.0  329.0
# Washington       Chamomile   171.0  334.0
# Washington       Chamomile   179.0  347.0
# Wisconsin        Columbian    35.0  317.0
# Wisconsin        Columbian    48.0  314.0
#
# [669 rows x 3 columns]

# %% [markdown]
# ## Get to know the name in prodcut

# %%
data['Product'].unique()
# Out:
# array(['Amaretto', 'Green Tea', 'Caffe Mocha', 'Decaf Espresso',
#        'Chamomile', 'Lemon', 'Mint', 'Darjeeling', 'Earl Grey',
#        'Columbian', 'Caffe Latte', 'Decaf Irish Cream',
#        'Regular Espresso'], dtype=object)

# %% [markdown]
# ## Filter the catgories name in column product

# %%
products = ['Caffe Latte', 'Mint']
filt = data['Product'].isin(products)
data.loc[filt]
# Out:
#             Total Expenses      Product  Sales   Market Size  Profit Market  \
# State
# California            25.0         Mint   90.0  Major Market    26.0   West
# California            28.0         Mint  119.0  Major Market    52.0   West
# California            92.0  Caffe Latte  527.0  Major Market   230.0   West
# California            92.0  Caffe Latte  527.0  Major Market   230.0   West
# California            30.0         Mint  120.0  Major Market    38.0   West
# ...                    ...          ...    ...           ...     ...    ...
# Washington            28.0  Caffe Latte  119.0  Small Market    52.0   West
# Washington            26.0  Caffe Latte  110.0  Small Market    47.0   West
# Washington            20.0  Caffe Latte   68.0  Small Market    23.0   West
# Washington            19.0  Caffe Latte   55.0  Small Market    16.0   West
# Washington            26.0  Caffe Latte  109.0  Small Market    47.0   West
#
# ...
